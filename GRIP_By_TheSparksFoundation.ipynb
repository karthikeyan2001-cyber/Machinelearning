# %% [markdown]
# # Prediction using Unsupervised Machine Learning

# %% [markdown]
# ###### <font color='BLUE'>Predict the optimum number of clusters from the "Iris" dataset and represent it visually.</font>

# %% [markdown]
# #                   <font color='blue'>Done By - KARTHIKEYAN R</font>

# %% [markdown]
# ### Analysation of Dataset

# %%
library(ggplot2)
summary(iris)
sapply(iris[,-5], var)
# Out:
# Registered S3 methods overwritten by 'ggplot2':
#   method         from
#   [.quosures     rlang
#   c.quosures     rlang
#   print.quosures rlang
#   Sepal.Length    Sepal.Width     Petal.Length    Petal.Width
#  Min.   :4.300   Min.   :2.000   Min.   :1.000   Min.   :0.100
#  1st Qu.:5.100   1st Qu.:2.800   1st Qu.:1.600   1st Qu.:0.300
#  Median :5.800   Median :3.000   Median :4.350   Median :1.300
#  Mean   :5.843   Mean   :3.057   Mean   :3.758   Mean   :1.199
#  3rd Qu.:6.400   3rd Qu.:3.300   3rd Qu.:5.100   3rd Qu.:1.800
#  Max.   :7.900   Max.   :4.400   Max.   :6.900   Max.   :2.500
#        Species
#  setosa    :50
#  versicolor:50
#  virginica :50
# Sepal.Length  Sepal.Width Petal.Length  Petal.Width
#    0.6856935    0.1899794    3.1162779    0.5810063

# %% [markdown]
# ## VISUALIZATION using ggplot

# %% [markdown]
# ###  <font color='red'>SCATTER PLOT</font>

# %%
ggplot(iris,aes(x = Sepal.Length, y = Sepal.Width, col= Species)) + geom_point()
# Out:
# plot without title

# %% [markdown]
# ####  <font color='red'>SMOOTH LINE PLOT</font>

# %%
pl=ggplot(data=iris,aes(x=Petal.Length,y=Petal.Width,col= Species))
pl1=print(pl+stat_smooth())
# Out:
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# plot without title

# %% [markdown]
# # Finding number of clusters using elbow method

# %%
set.seed(200)
k.max <- 10
wss<- sapply(1:k.max,function(k){kmeans(iris[,3:4],k,nstart = 20,iter.max = 20)$tot.withinss})
wss
plot(1:k.max,wss, type= "b", xlab = "Number of clusters(k)", ylab = "Within cluster sum of squares")
# Out:
#  [1] 550.895333  86.390220  31.371359  19.465989  13.916909  11.025145
#  [7]   9.236596   7.674414   6.456495   5.550520
# plot without title

# %% [markdown]
# ### From the above Elbow Plot, we find that number of clusters = 3

# %%
ircluster <- kmeans(iris[,3:4],3,nstart = 20)
table(ircluster$cluster,iris$Species)
# Out:
#
#     setosa versicolor virginica
#   1      0          2        46
#   2     50          0         0
#   3      0         48         4

# %% [markdown]
# ### From the table we can see most of the observations have been clustered correctly however, 2 of the versicolor have been put in the cluster with all the virginica and 4 of the verginica have been put in cluster 3 which mostly has versicolor.

# %% [markdown]
# ### <font color='red' size='50px'>THANK YOU</font>
